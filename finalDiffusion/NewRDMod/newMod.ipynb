# %% [markdown]
# # Diffusion model for clutter denoising

# %% [markdown]
# ## Initialization

# %% [markdown]
# ### Imports

# %%
import os
import math
import torch
import wandb
import numpy as np
from tqdm import tqdm
import torch.nn as nn
from torch import einsum
from models.unet import *
import torch.optim as optim
from utils.trainer import *
#from models.newdif import *
from torch.optim import Adam
from utils.plotters import *
from utils.inference import *
from models.diffusion import *
from dataset.radardata import *
import torch.nn.functional as F
import matplotlib.pyplot as plt
from types import SimpleNamespace
from torch.utils.data import Dataset, DataLoader, ConcatDataset, random_split

# %% [markdown]
# ### Define device

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Initialiaze W&B + config

# %%
run_name = 'try_bench_again_bend005'

# %%
wandb.init(
    project="New-Radar-diffusion2",
    name=run_name,
    notes="Regular diffusion. this experiment is our benchmark - we check if changes are performing better or worse",
    config={
        "beta_end": 0.02,
        "beta_start": 1e-4,
        "batch_size": 16,
        "num_epochs": 400,
        "noise_steps": 2000,
        "num_workers": 4,
        "time_emb_dim": 256,
        "learning_rate": 1e-4,        
        "scheduler_type": "linear",
    },
)
config = wandb.config
# Out:
# Finishing last run (ID:obaj15fz) before initializing another...
# VBox(children=(Label(value='0.004 MB of 0.004 MB uploaded\r'), FloatProgress(value=0.993600379236786, max=1.0)…
#  View run <strong style="color:#cdcd00">try_bench_again_bend005</strong> at: <a href='https://wandb.ai/ari-granevich/New-Radar-diffusion/runs/obaj15fz' target="_blank">https://wandb.ai/ari-granevich/New-Radar-diffusion/runs/obaj15fz</a><br/> View project at: <a href='https://wandb.ai/ari-granevich/New-Radar-diffusion' target="_blank">https://wandb.ai/ari-granevich/New-Radar-diffusion</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250414_100932-obaj15fz/logs</code>
# Successfully finished last run (ID:obaj15fz). Initializing new run:<br/>
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.011112310240666072, max=1.0…
# wandb version 0.19.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.1
# Run data is saved locally in <code>/home/hawk/Desktop/Heavy Detector/Heavy-Clutter-Detection/finalDiffusion/wandb/run-20250414_101006-koaixjo7</code>
# Syncing run <strong><a href='https://wandb.ai/ari-granevich/New-Radar-diffusion/runs/koaixjo7' target="_blank">try_bench_again_bend005</a></strong> to <a href='https://wandb.ai/ari-granevich/New-Radar-diffusion' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ari-granevich/New-Radar-diffusion' target="_blank">https://wandb.ai/ari-granevich/New-Radar-diffusion</a>
#  View run at <a href='https://wandb.ai/ari-granevich/New-Radar-diffusion/runs/koaixjo7' target="_blank">https://wandb.ai/ari-granevich/New-Radar-diffusion/runs/koaixjo7</a>

# %% [markdown]
# ## dataset prep

# %%
norm_train_dataset = torch.load("norm_train_dataset.pt")
norm_val_dataset   = torch.load("norm_val_dataset.pt")
norm_train_loader = DataLoader(norm_train_dataset, batch_size=config.batch_size, shuffle=True,  num_workers=config.num_workers)
norm_val_loader   = DataLoader(norm_val_dataset,   batch_size=config.batch_size, shuffle=False, num_workers=config.num_workers)
# Out:
# Normalizing dataset: 100%|██████████| 55000/55000 [01:14<00:00, 738.70it/s]
# Normalizing dataset: 100%|██████████| 5500/5500 [00:07<00:00, 688.79it/s]

# %% [markdown]
# ## train

# %%
train_loader = norm_train_loader
val_loader = norm_val_loader
cond_unet = ConditionalUNet(in_channels=4, out_channels=2, time_emb_dim=config.time_emb_dim).to(device)
cond_diffusion = ConditionalDiffusion(model=cond_unet, scheduler_type=config.scheduler_type, T=config.noise_steps, 
    beta_start=config.beta_start, beta_end=config.beta_end).to(device)
optimizer = torch.optim.Adam(cond_diffusion.parameters(), config.learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, threshold=1e-4, cooldown=15, min_lr=1e-6, verbose=True)
num_epochs = config.num_epochs
# Out:
# /home/hawk/.local/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "

# %%
best_val_loss = float('inf')
best_mse_loss = float('inf')
train_losses, val_losses, val_psnrs, val_mses = [], [], [], []
e_mse_loss = None
e_rd_loss = None
iq_val_loss = None
rd_val_loss = None

for epoch in range(num_epochs):
    #train_loss, e_mse_loss, e_rd_loss= train_one_epoch(cond_diffusion, train_loader, optimizer, device)
    #val_loss, iq_val_loss, rd_val_loss, gen_mse, gen_psnr, rd_mse = validate(cond_diffusion, val_loader, device)

    train_loss= train_one_epoch(cond_diffusion, train_loader, optimizer, device)
    val_loss, gen_mse, gen_psnr = validate(cond_diffusion, val_loader, device)

    train_losses.append(train_loss)
    val_losses.append(val_loss)

    if gen_psnr is not None:
        val_psnrs.append(gen_psnr)
    if gen_mse is not None:
        val_mses.append(gen_mse)

    print(f"Epoch {epoch+1}/{num_epochs}: Train Loss = {train_loss:.4f} | Val Loss = {val_loss:.4f}")

    if gen_mse is not None and gen_psnr is not None:
        print(f"   [Generation Metrics] MSE: {gen_mse:.4f} | PSNR: {gen_psnr:.2f} dB")

    scheduler.step(val_loss)

    if gen_mse < best_mse_loss:
        best_mse_loss = gen_mse
        torch.save(cond_diffusion.state_dict(), f"{run_name}.pth")
        print("   --> Best MSE model saved.")

    wandb.log({
        "total train loss": train_loss,
        "train mse loss": e_mse_loss if e_mse_loss is not None else float('nan'),
        "train rd loss": e_rd_loss if e_rd_loss is not None else float('nan'),
        "total val loss": val_loss,
        "IQ val loss": iq_val_loss if iq_val_loss is not None else float('nan'), 
        "RD val loss": rd_val_loss if rd_val_loss is not None else float('nan'),
        #"MSE between denoised RD and clean RD": rd_mse,
        "MSE between denoised IQ and clean IQ": gen_mse if gen_mse is not None else float('nan'),
        "generated IQ map PSNR": gen_psnr,
        "learning rate": optimizer.param_groups[0]['lr']  # Optional, log current LR
    })
# Out:
# Epoch 1/400: Train Loss = 0.1751 | Val Loss = 0.1246
#    [Generation Metrics] MSE: 18.4005 | PSNR: -1.55 dB
#    --> Best MSE model saved.
# Epoch 2/400: Train Loss = 0.1097 | Val Loss = 0.1028
#    [Generation Metrics] MSE: 1.3209 | PSNR: 9.89 dB
#    --> Best MSE model saved.
# Epoch 3/400: Train Loss = 0.0968 | Val Loss = 0.0935
#    [Generation Metrics] MSE: 1.4502 | PSNR: 9.48 dB
# Epoch 4/400: Train Loss = 0.0893 | Val Loss = 0.0871
#    [Generation Metrics] MSE: 1.0805 | PSNR: 10.76 dB
#    --> Best MSE model saved.
# Epoch 5/400: Train Loss = 0.0851 | Val Loss = 0.0834
#    [Generation Metrics] MSE: 1.0967 | PSNR: 10.70 dB
# Epoch 6/400: Train Loss = 0.0822 | Val Loss = 0.0792
#    [Generation Metrics] MSE: 1.0108 | PSNR: 11.05 dB
#    --> Best MSE model saved.
# Epoch 7/400: Train Loss = 0.0761 | Val Loss = 0.0732
#    [Generation Metrics] MSE: 0.8778 | PSNR: 11.66 dB
#    --> Best MSE model saved.
# Epoch 8/400: Train Loss = 0.0723 | Val Loss = 0.0729
#    [Generation Metrics] MSE: 0.8905 | PSNR: 11.60 dB
# Epoch 9/400: Train Loss = 0.0679 | Val Loss = 0.0704
#    [Generation Metrics] MSE: 1.4138 | PSNR: 9.59 dB
# Epoch 10/400: Train Loss = 0.0666 | Val Loss = 0.0635
#    [Generation Metrics] MSE: 0.7938 | PSNR: 12.10 dB
#    --> Best MSE model saved.
# Epoch 11/400: Train Loss = 0.0651 | Val Loss = 0.0632
#    [Generation Metrics] MSE: 0.8960 | PSNR: 11.57 dB
# Epoch 12/400: Train Loss = 0.0633 | Val Loss = 0.0641
#    [Generation Metrics] MSE: 0.9164 | PSNR: 11.48 dB
# Epoch 13/400: Train Loss = 0.0611 | Val Loss = 0.0618
#    [Generation Metrics] MSE: 0.6939 | PSNR: 12.68 dB
#    --> Best MSE model saved.
# Epoch 14/400: Train Loss = 0.0609 | Val Loss = 0.0635
#    [Generation Metrics] MSE: 0.7630 | PSNR: 12.27 dB
# Epoch 15/400: Train Loss = 0.0594 | Val Loss = 0.0584
#    [Generation Metrics] MSE: 1.0372 | PSNR: 10.94 dB
# Epoch 16/400: Train Loss = 0.0583 | Val Loss = 0.0596
#    [Generation Metrics] MSE: 1.1005 | PSNR: 10.68 dB
# Epoch 17/400: Train Loss = 0.0579 | Val Loss = 0.0607
#    [Generation Metrics] MSE: 0.6970 | PSNR: 12.66 dB
# Epoch 18/400: Train Loss = 0.0573 | Val Loss = 0.0565
#    [Generation Metrics] MSE: 0.6394 | PSNR: 13.04 dB
#    --> Best MSE model saved.
# Epoch 19/400: Train Loss = 0.0561 | Val Loss = 0.0587
#    [Generation Metrics] MSE: 0.7296 | PSNR: 12.47 dB
# Epoch 20/400: Train Loss = 0.0552 | Val Loss = 0.0574
#    [Generation Metrics] MSE: 0.8120 | PSNR: 12.00 dB
# Epoch 21/400: Train Loss = 0.0555 | Val Loss = 0.0528
#    [Generation Metrics] MSE: 0.8426 | PSNR: 11.84 dB
# Epoch 22/400: Train Loss = 0.0543 | Val Loss = 0.0537
#    [Generation Metrics] MSE: 0.7708 | PSNR: 12.23 dB
# Epoch 23/400: Train Loss = 0.0532 | Val Loss = 0.0507
#    [Generation Metrics] MSE: 0.8351 | PSNR: 11.88 dB
# Epoch 24/400: Train Loss = 0.0533 | Val Loss = 0.0529
#    [Generation Metrics] MSE: 0.5920 | PSNR: 13.37 dB
#    --> Best MSE model saved.
# Epoch 25/400: Train Loss = 0.0527 | Val Loss = 0.0491
#    [Generation Metrics] MSE: 0.6021 | PSNR: 13.30 dB
# Epoch 26/400: Train Loss = 0.0523 | Val Loss = 0.0505
#    [Generation Metrics] MSE: 1.6773 | PSNR: 8.85 dB
# Epoch 27/400: Train Loss = 0.0507 | Val Loss = 0.0516
#    [Generation Metrics] MSE: 0.5503 | PSNR: 13.69 dB
#    --> Best MSE model saved.
# Epoch 28/400: Train Loss = 0.0511 | Val Loss = 0.0516
#    [Generation Metrics] MSE: 0.4698 | PSNR: 14.38 dB
#    --> Best MSE model saved.
# Epoch 29/400: Train Loss = 0.0507 | Val Loss = 0.0490
#    [Generation Metrics] MSE: 1.0221 | PSNR: 11.00 dB
# Epoch 30/400: Train Loss = 0.0496 | Val Loss = 0.0526
#    [Generation Metrics] MSE: 0.7922 | PSNR: 12.11 dB
# Epoch 31/400: Train Loss = 0.0496 | Val Loss = 0.0504
#    [Generation Metrics] MSE: 0.9835 | PSNR: 11.17 dB
# Epoch 32/400: Train Loss = 0.0496 | Val Loss = 0.0490
#    [Generation Metrics] MSE: 0.5650 | PSNR: 13.58 dB
# Epoch 33/400: Train Loss = 0.0493 | Val Loss = 0.0507
#    [Generation Metrics] MSE: 0.7106 | PSNR: 12.58 dB
# Epoch 34/400: Train Loss = 0.0495 | Val Loss = 0.0466
#    [Generation Metrics] MSE: 0.5472 | PSNR: 13.72 dB
# Epoch 35/400: Train Loss = 0.0495 | Val Loss = 0.0499
#    [Generation Metrics] MSE: 0.9511 | PSNR: 11.31 dB
# Epoch 36/400: Train Loss = 0.0487 | Val Loss = 0.0502
#    [Generation Metrics] MSE: 0.5139 | PSNR: 13.99 dB
# Epoch 37/400: Train Loss = 0.0478 | Val Loss = 0.0470
#    [Generation Metrics] MSE: 0.5188 | PSNR: 13.95 dB
# Epoch 38/400: Train Loss = 0.0475 | Val Loss = 0.0500
#    [Generation Metrics] MSE: 0.6396 | PSNR: 13.04 dB
# Epoch 39/400: Train Loss = 0.0469 | Val Loss = 0.0480
#    [Generation Metrics] MSE: 0.6765 | PSNR: 12.79 dB
# Epoch 40/400: Train Loss = 0.0468 | Val Loss = 0.0493
#    [Generation Metrics] MSE: 0.4842 | PSNR: 14.25 dB
# Epoch 41/400: Train Loss = 0.0471 | Val Loss = 0.0484
#    [Generation Metrics] MSE: 0.6751 | PSNR: 12.80 dB
# Epoch 42/400: Train Loss = 0.0460 | Val Loss = 0.0441
#    [Generation Metrics] MSE: 0.4193 | PSNR: 14.87 dB
#    --> Best MSE model saved.
# Epoch 43/400: Train Loss = 0.0456 | Val Loss = 0.0470
#    [Generation Metrics] MSE: 0.6597 | PSNR: 12.90 dB
# Epoch 44/400: Train Loss = 0.0459 | Val Loss = 0.0460
#    [Generation Metrics] MSE: 0.4597 | PSNR: 14.47 dB
# Epoch 45/400: Train Loss = 0.0464 | Val Loss = 0.0471
#    [Generation Metrics] MSE: 0.6785 | PSNR: 12.78 dB
# Epoch 46/400: Train Loss = 0.0460 | Val Loss = 0.0447
#    [Generation Metrics] MSE: 0.5648 | PSNR: 13.58 dB
# Epoch 47/400: Train Loss = 0.0446 | Val Loss = 0.0424
#    [Generation Metrics] MSE: 0.4618 | PSNR: 14.45 dB
# Epoch 48/400: Train Loss = 0.0458 | Val Loss = 0.0442
#    [Generation Metrics] MSE: 0.4455 | PSNR: 14.61 dB
# Epoch 49/400: Train Loss = 0.0452 | Val Loss = 0.0435
#    [Generation Metrics] MSE: 0.5532 | PSNR: 13.67 dB
# Epoch 50/400: Train Loss = 0.0446 | Val Loss = 0.0472
#    [Generation Metrics] MSE: 0.6300 | PSNR: 13.10 dB
# Epoch 51/400: Train Loss = 0.0453 | Val Loss = 0.0497
#    [Generation Metrics] MSE: 0.5040 | PSNR: 14.07 dB
# Epoch 52/400: Train Loss = 0.0447 | Val Loss = 0.0446
#    [Generation Metrics] MSE: 0.5594 | PSNR: 13.62 dB
# Epoch 53/400: Train Loss = 0.0444 | Val Loss = 0.0450
#    [Generation Metrics] MSE: 0.5190 | PSNR: 13.95 dB
# Epoch 54/400: Train Loss = 0.0444 | Val Loss = 0.0459
#    [Generation Metrics] MSE: 0.5783 | PSNR: 13.47 dB
# Epoch 55/400: Train Loss = 0.0430 | Val Loss = 0.0443
#    [Generation Metrics] MSE: 0.4638 | PSNR: 14.43 dB
# Epoch 56/400: Train Loss = 0.0439 | Val Loss = 0.0444
#    [Generation Metrics] MSE: 0.5237 | PSNR: 13.91 dB
# Epoch 57/400: Train Loss = 0.0439 | Val Loss = 0.0464
#    [Generation Metrics] MSE: 0.5711 | PSNR: 13.53 dB
# Epoch 58/400: Train Loss = 0.0437 | Val Loss = 0.0423
#    [Generation Metrics] MSE: 0.4532 | PSNR: 14.53 dB
# Epoch 59/400: Train Loss = 0.0434 | Val Loss = 0.0431
#    [Generation Metrics] MSE: 0.5155 | PSNR: 13.97 dB
# Epoch 60/400: Train Loss = 0.0422 | Val Loss = 0.0442
#    [Generation Metrics] MSE: 0.4327 | PSNR: 14.73 dB
# Epoch 61/400: Train Loss = 0.0425 | Val Loss = 0.0453
#    [Generation Metrics] MSE: 0.4704 | PSNR: 14.37 dB
# Epoch 62/400: Train Loss = 0.0431 | Val Loss = 0.0449
#    [Generation Metrics] MSE: 0.3997 | PSNR: 15.08 dB
#    --> Best MSE model saved.
# Epoch 63/400: Train Loss = 0.0426 | Val Loss = 0.0446
#    [Generation Metrics] MSE: 0.6960 | PSNR: 12.67 dB
# Epoch 64/400: Train Loss = 0.0421 | Val Loss = 0.0433
#    [Generation Metrics] MSE: 0.4347 | PSNR: 14.71 dB
# Epoch 65/400: Train Loss = 0.0416 | Val Loss = 0.0452
#    [Generation Metrics] MSE: 0.5936 | PSNR: 13.36 dB
# Epoch 66/400: Train Loss = 0.0429 | Val Loss = 0.0434
#    [Generation Metrics] MSE: 0.4313 | PSNR: 14.75 dB
# Epoch 67/400: Train Loss = 0.0417 | Val Loss = 0.0407
#    [Generation Metrics] MSE: 0.4926 | PSNR: 14.17 dB
# Epoch 68/400: Train Loss = 0.0428 | Val Loss = 0.0430
#    [Generation Metrics] MSE: 0.5847 | PSNR: 13.43 dB
# Epoch 69/400: Train Loss = 0.0421 | Val Loss = 0.0439
#    [Generation Metrics] MSE: 0.4637 | PSNR: 14.43 dB
# Epoch 70/400: Train Loss = 0.0413 | Val Loss = 0.0405
#    [Generation Metrics] MSE: 0.6249 | PSNR: 13.14 dB
# Epoch 71/400: Train Loss = 0.0414 | Val Loss = 0.0419
#    [Generation Metrics] MSE: 0.4650 | PSNR: 14.42 dB
# Epoch 72/400: Train Loss = 0.0417 | Val Loss = 0.0406
#    [Generation Metrics] MSE: 0.5830 | PSNR: 13.44 dB
# Epoch 73/400: Train Loss = 0.0410 | Val Loss = 0.0421
#    [Generation Metrics] MSE: 0.5981 | PSNR: 13.33 dB
# Epoch 74/400: Train Loss = 0.0407 | Val Loss = 0.0434
#    [Generation Metrics] MSE: 0.5378 | PSNR: 13.79 dB
# Epoch 75/400: Train Loss = 0.0414 | Val Loss = 0.0430
#    [Generation Metrics] MSE: 0.4661 | PSNR: 14.41 dB
# Epoch 76/400: Train Loss = 0.0407 | Val Loss = 0.0428
#    [Generation Metrics] MSE: 0.4999 | PSNR: 14.11 dB
# Epoch 77/400: Train Loss = 0.0413 | Val Loss = 0.0404
#    [Generation Metrics] MSE: 0.7175 | PSNR: 12.54 dB
# Epoch 78/400: Train Loss = 0.0405 | Val Loss = 0.0411
#    [Generation Metrics] MSE: 0.5088 | PSNR: 14.03 dB
# Epoch 79/400: Train Loss = 0.0413 | Val Loss = 0.0422
#    [Generation Metrics] MSE: 0.4499 | PSNR: 14.57 dB
# Epoch 80/400: Train Loss = 0.0393 | Val Loss = 0.0382
#    [Generation Metrics] MSE: 0.4762 | PSNR: 14.32 dB
# Epoch 81/400: Train Loss = 0.0411 | Val Loss = 0.0385
#    [Generation Metrics] MSE: 0.6353 | PSNR: 13.07 dB
# Epoch 82/400: Train Loss = 0.0406 | Val Loss = 0.0407
#    [Generation Metrics] MSE: 0.5551 | PSNR: 13.65 dB
# Epoch 83/400: Train Loss = 0.0398 | Val Loss = 0.0410
#    [Generation Metrics] MSE: 0.6668 | PSNR: 12.86 dB
# Epoch 84/400: Train Loss = 0.0398 | Val Loss = 0.0405
#    [Generation Metrics] MSE: 0.4440 | PSNR: 14.62 dB
# Epoch 85/400: Train Loss = 0.0405 | Val Loss = 0.0391
#    [Generation Metrics] MSE: 0.4606 | PSNR: 14.46 dB
# Epoch 86/400: Train Loss = 0.0398 | Val Loss = 0.0420
#    [Generation Metrics] MSE: 1.0170 | PSNR: 11.02 dB
# Epoch 87/400: Train Loss = 0.0399 | Val Loss = 0.0419
#    [Generation Metrics] MSE: 0.4403 | PSNR: 14.66 dB
# Epoch 88/400: Train Loss = 0.0393 | Val Loss = 0.0417
#    [Generation Metrics] MSE: 0.4568 | PSNR: 14.50 dB
# Epoch 89/400: Train Loss = 0.0393 | Val Loss = 0.0393
#    [Generation Metrics] MSE: 0.4002 | PSNR: 15.07 dB
# Epoch 90/400: Train Loss = 0.0395 | Val Loss = 0.0389
#    [Generation Metrics] MSE: 0.4792 | PSNR: 14.29 dB
# Epoch 91/400: Train Loss = 0.0393 | Val Loss = 0.0400
#    [Generation Metrics] MSE: 0.4516 | PSNR: 14.55 dB
# Epoch 92/400: Train Loss = 0.0382 | Val Loss = 0.0380
#    [Generation Metrics] MSE: 0.5757 | PSNR: 13.49 dB
# Epoch 93/400: Train Loss = 0.0376 | Val Loss = 0.0384
#    [Generation Metrics] MSE: 0.4019 | PSNR: 15.06 dB
# Epoch 94/400: Train Loss = 0.0376 | Val Loss = 0.0369
#    [Generation Metrics] MSE: 0.5175 | PSNR: 13.96 dB
# Epoch 95/400: Train Loss = 0.0377 | Val Loss = 0.0364
#    [Generation Metrics] MSE: 0.4691 | PSNR: 14.38 dB
# Epoch 96/400: Train Loss = 0.0381 | Val Loss = 0.0378
#    [Generation Metrics] MSE: 0.4821 | PSNR: 14.27 dB
# Epoch 97/400: Train Loss = 0.0374 | Val Loss = 0.0373
#    [Generation Metrics] MSE: 0.4430 | PSNR: 14.63 dB
# Epoch 98/400: Train Loss = 0.0371 | Val Loss = 0.0388
#    [Generation Metrics] MSE: 0.4816 | PSNR: 14.27 dB
# Epoch 99/400: Train Loss = 0.0368 | Val Loss = 0.0385
#    [Generation Metrics] MSE: 0.5366 | PSNR: 13.80 dB
# Epoch 100/400: Train Loss = 0.0373 | Val Loss = 0.0372
#    [Generation Metrics] MSE: 0.4273 | PSNR: 14.79 dB
# Epoch 101/400: Train Loss = 0.0368 | Val Loss = 0.0355
#    [Generation Metrics] MSE: 0.5213 | PSNR: 13.93 dB
# Epoch 102/400: Train Loss = 0.0376 | Val Loss = 0.0375
#    [Generation Metrics] MSE: 0.4902 | PSNR: 14.19 dB
# Epoch 103/400: Train Loss = 0.0372 | Val Loss = 0.0366
#    [Generation Metrics] MSE: 0.4421 | PSNR: 14.64 dB
# Epoch 104/400: Train Loss = 0.0363 | Val Loss = 0.0374
#    [Generation Metrics] MSE: 0.4039 | PSNR: 15.03 dB
# Epoch 105/400: Train Loss = 0.0369 | Val Loss = 0.0358
#    [Generation Metrics] MSE: 0.4998 | PSNR: 14.11 dB
# Epoch 106/400: Train Loss = 0.0365 | Val Loss = 0.0386
#    [Generation Metrics] MSE: 0.4169 | PSNR: 14.90 dB
# Epoch 107/400: Train Loss = 0.0356 | Val Loss = 0.0374
#    [Generation Metrics] MSE: 0.3863 | PSNR: 15.23 dB
#    --> Best MSE model saved.
# Epoch 108/400: Train Loss = 0.0363 | Val Loss = 0.0383
#    [Generation Metrics] MSE: 0.4730 | PSNR: 14.35 dB
# Epoch 109/400: Train Loss = 0.0372 | Val Loss = 0.0371
#    [Generation Metrics] MSE: 0.4059 | PSNR: 15.01 dB
# Epoch 110/400: Train Loss = 0.0366 | Val Loss = 0.0361
#    [Generation Metrics] MSE: 0.4260 | PSNR: 14.80 dB
# Epoch 111/400: Train Loss = 0.0366 | Val Loss = 0.0361
#    [Generation Metrics] MSE: 0.5363 | PSNR: 13.80 dB
# Epoch 112/400: Train Loss = 0.0364 | Val Loss = 0.0393
#    [Generation Metrics] MSE: 0.5837 | PSNR: 13.44 dB
# Epoch 113/400: Train Loss = 0.0362 | Val Loss = 0.0369
#    [Generation Metrics] MSE: 0.4323 | PSNR: 14.74 dB
# Epoch 114/400: Train Loss = 0.0365 | Val Loss = 0.0363
#    [Generation Metrics] MSE: 0.5146 | PSNR: 13.98 dB
# Epoch 115/400: Train Loss = 0.0367 | Val Loss = 0.0364
#    [Generation Metrics] MSE: 0.3895 | PSNR: 15.19 dB
# Epoch 116/400: Train Loss = 0.0367 | Val Loss = 0.0394
#    [Generation Metrics] MSE: 0.4298 | PSNR: 14.76 dB
# Epoch 117/400: Train Loss = 0.0368 | Val Loss = 0.0379
#    [Generation Metrics] MSE: 0.4159 | PSNR: 14.91 dB
# Epoch 118/400: Train Loss = 0.0355 | Val Loss = 0.0350
#    [Generation Metrics] MSE: 0.5075 | PSNR: 14.04 dB
# Epoch 119/400: Train Loss = 0.0350 | Val Loss = 0.0369
#    [Generation Metrics] MSE: 0.4401 | PSNR: 14.66 dB
# Epoch 120/400: Train Loss = 0.0352 | Val Loss = 0.0355
#    [Generation Metrics] MSE: 0.4437 | PSNR: 14.63 dB
# Epoch 121/400: Train Loss = 0.0361 | Val Loss = 0.0361
#    [Generation Metrics] MSE: 0.4556 | PSNR: 14.51 dB
# Epoch 122/400: Train Loss = 0.0352 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4239 | PSNR: 14.82 dB
# Epoch 123/400: Train Loss = 0.0354 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4139 | PSNR: 14.93 dB
# Epoch 124/400: Train Loss = 0.0354 | Val Loss = 0.0352
#    [Generation Metrics] MSE: 0.4048 | PSNR: 15.02 dB
# Epoch 125/400: Train Loss = 0.0347 | Val Loss = 0.0364
#    [Generation Metrics] MSE: 0.4130 | PSNR: 14.94 dB
# Epoch 126/400: Train Loss = 0.0354 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.4808 | PSNR: 14.28 dB
# Epoch 127/400: Train Loss = 0.0349 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4081 | PSNR: 14.99 dB
# Epoch 128/400: Train Loss = 0.0349 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.3998 | PSNR: 15.08 dB
# Epoch 129/400: Train Loss = 0.0350 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.3663 | PSNR: 15.46 dB
#    --> Best MSE model saved.
# Epoch 130/400: Train Loss = 0.0351 | Val Loss = 0.0368
#    [Generation Metrics] MSE: 0.5063 | PSNR: 14.05 dB
# Epoch 131/400: Train Loss = 0.0351 | Val Loss = 0.0352
#    [Generation Metrics] MSE: 0.4414 | PSNR: 14.65 dB
# Epoch 132/400: Train Loss = 0.0353 | Val Loss = 0.0349
#    [Generation Metrics] MSE: 0.4017 | PSNR: 15.06 dB
# Epoch 133/400: Train Loss = 0.0353 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4426 | PSNR: 14.64 dB
# Epoch 134/400: Train Loss = 0.0348 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.3890 | PSNR: 15.20 dB
# Epoch 135/400: Train Loss = 0.0349 | Val Loss = 0.0364
#    [Generation Metrics] MSE: 0.3635 | PSNR: 15.49 dB
#    --> Best MSE model saved.
# Epoch 136/400: Train Loss = 0.0359 | Val Loss = 0.0380
#    [Generation Metrics] MSE: 0.4089 | PSNR: 14.98 dB
# Epoch 137/400: Train Loss = 0.0346 | Val Loss = 0.0365
#    [Generation Metrics] MSE: 0.4950 | PSNR: 14.15 dB
# Epoch 138/400: Train Loss = 0.0345 | Val Loss = 0.0380
#    [Generation Metrics] MSE: 0.4142 | PSNR: 14.92 dB
# Epoch 139/400: Train Loss = 0.0355 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4446 | PSNR: 14.62 dB
# Epoch 140/400: Train Loss = 0.0344 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.4343 | PSNR: 14.72 dB
# Epoch 141/400: Train Loss = 0.0354 | Val Loss = 0.0366
#    [Generation Metrics] MSE: 0.3761 | PSNR: 15.34 dB
# Epoch 142/400: Train Loss = 0.0350 | Val Loss = 0.0370
#    [Generation Metrics] MSE: 0.3931 | PSNR: 15.15 dB
# Epoch 143/400: Train Loss = 0.0344 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4610 | PSNR: 14.46 dB
# Epoch 144/400: Train Loss = 0.0348 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4400 | PSNR: 14.66 dB
# Epoch 145/400: Train Loss = 0.0343 | Val Loss = 0.0327
#    [Generation Metrics] MSE: 0.5137 | PSNR: 13.99 dB
# Epoch 146/400: Train Loss = 0.0345 | Val Loss = 0.0341
#    [Generation Metrics] MSE: 0.4430 | PSNR: 14.63 dB
# Epoch 147/400: Train Loss = 0.0339 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.4282 | PSNR: 14.78 dB
# Epoch 148/400: Train Loss = 0.0350 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.5088 | PSNR: 14.03 dB
# Epoch 149/400: Train Loss = 0.0344 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4250 | PSNR: 14.81 dB
# Epoch 150/400: Train Loss = 0.0345 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.4244 | PSNR: 14.82 dB
# Epoch 151/400: Train Loss = 0.0343 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.3947 | PSNR: 15.13 dB
# Epoch 152/400: Train Loss = 0.0344 | Val Loss = 0.0354
#    [Generation Metrics] MSE: 0.3687 | PSNR: 15.43 dB
# Epoch 153/400: Train Loss = 0.0345 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.3848 | PSNR: 15.24 dB
# Epoch 154/400: Train Loss = 0.0341 | Val Loss = 0.0347
#    [Generation Metrics] MSE: 0.4513 | PSNR: 14.55 dB
# Epoch 155/400: Train Loss = 0.0342 | Val Loss = 0.0347
#    [Generation Metrics] MSE: 0.4430 | PSNR: 14.63 dB
# Epoch 156/400: Train Loss = 0.0339 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4371 | PSNR: 14.69 dB
# Epoch 157/400: Train Loss = 0.0335 | Val Loss = 0.0328
#    [Generation Metrics] MSE: 0.4812 | PSNR: 14.27 dB
# Epoch 158/400: Train Loss = 0.0338 | Val Loss = 0.0366
#    [Generation Metrics] MSE: 0.4031 | PSNR: 15.04 dB
# Epoch 159/400: Train Loss = 0.0339 | Val Loss = 0.0353
#    [Generation Metrics] MSE: 0.4095 | PSNR: 14.97 dB
# Epoch 160/400: Train Loss = 0.0339 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.3742 | PSNR: 15.36 dB
# Epoch 161/400: Train Loss = 0.0341 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4462 | PSNR: 14.60 dB
# Epoch 162/400: Train Loss = 0.0343 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.3940 | PSNR: 15.14 dB
# Epoch 163/400: Train Loss = 0.0348 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4176 | PSNR: 14.89 dB
# Epoch 164/400: Train Loss = 0.0346 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.3511 | PSNR: 15.64 dB
#    --> Best MSE model saved.
# Epoch 165/400: Train Loss = 0.0340 | Val Loss = 0.0355
#    [Generation Metrics] MSE: 0.4388 | PSNR: 14.67 dB
# Epoch 166/400: Train Loss = 0.0345 | Val Loss = 0.0345
#    [Generation Metrics] MSE: 0.4122 | PSNR: 14.95 dB
# Epoch 167/400: Train Loss = 0.0338 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4630 | PSNR: 14.44 dB
# Epoch 168/400: Train Loss = 0.0342 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4525 | PSNR: 14.54 dB
# Epoch 169/400: Train Loss = 0.0340 | Val Loss = 0.0336
#    [Generation Metrics] MSE: 0.4548 | PSNR: 14.52 dB
# Epoch 170/400: Train Loss = 0.0347 | Val Loss = 0.0341
#    [Generation Metrics] MSE: 0.5122 | PSNR: 14.00 dB
# Epoch 171/400: Train Loss = 0.0338 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.4186 | PSNR: 14.88 dB
# Epoch 172/400: Train Loss = 0.0345 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.3691 | PSNR: 15.42 dB
# Epoch 173/400: Train Loss = 0.0334 | Val Loss = 0.0323
#    [Generation Metrics] MSE: 0.4175 | PSNR: 14.89 dB
# Epoch 174/400: Train Loss = 0.0337 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.4735 | PSNR: 14.34 dB
# Epoch 175/400: Train Loss = 0.0339 | Val Loss = 0.0345
#    [Generation Metrics] MSE: 0.3811 | PSNR: 15.29 dB
# Epoch 176/400: Train Loss = 0.0339 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.4521 | PSNR: 14.54 dB
# Epoch 177/400: Train Loss = 0.0334 | Val Loss = 0.0353
#    [Generation Metrics] MSE: 0.4418 | PSNR: 14.64 dB
# Epoch 178/400: Train Loss = 0.0338 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.3881 | PSNR: 15.21 dB
# Epoch 179/400: Train Loss = 0.0340 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.4133 | PSNR: 14.93 dB
# Epoch 180/400: Train Loss = 0.0337 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.3947 | PSNR: 15.13 dB
# Epoch 181/400: Train Loss = 0.0337 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.4487 | PSNR: 14.58 dB
# Epoch 182/400: Train Loss = 0.0333 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4204 | PSNR: 14.86 dB
# Epoch 183/400: Train Loss = 0.0335 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.3451 | PSNR: 15.72 dB
#    --> Best MSE model saved.
# Epoch 184/400: Train Loss = 0.0328 | Val Loss = 0.0356
#    [Generation Metrics] MSE: 0.4052 | PSNR: 15.02 dB
# Epoch 185/400: Train Loss = 0.0336 | Val Loss = 0.0350
#    [Generation Metrics] MSE: 0.3906 | PSNR: 15.18 dB
# Epoch 186/400: Train Loss = 0.0331 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.3759 | PSNR: 15.35 dB
# Epoch 187/400: Train Loss = 0.0331 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4194 | PSNR: 14.87 dB
# Epoch 188/400: Train Loss = 0.0334 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4584 | PSNR: 14.48 dB
# Epoch 189/400: Train Loss = 0.0331 | Val Loss = 0.0352
#    [Generation Metrics] MSE: 0.3751 | PSNR: 15.36 dB
# Epoch 190/400: Train Loss = 0.0341 | Val Loss = 0.0350
#    [Generation Metrics] MSE: 0.3871 | PSNR: 15.22 dB
# Epoch 191/400: Train Loss = 0.0333 | Val Loss = 0.0354
#    [Generation Metrics] MSE: 0.3418 | PSNR: 15.76 dB
#    --> Best MSE model saved.
# Epoch 192/400: Train Loss = 0.0332 | Val Loss = 0.0362
#    [Generation Metrics] MSE: 0.4599 | PSNR: 14.47 dB
# Epoch 193/400: Train Loss = 0.0335 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.4587 | PSNR: 14.48 dB
# Epoch 194/400: Train Loss = 0.0338 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.3683 | PSNR: 15.43 dB
# Epoch 195/400: Train Loss = 0.0340 | Val Loss = 0.0358
#    [Generation Metrics] MSE: 0.3803 | PSNR: 15.30 dB
# Epoch 196/400: Train Loss = 0.0338 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4484 | PSNR: 14.58 dB
# Epoch 197/400: Train Loss = 0.0329 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.3469 | PSNR: 15.69 dB
# Epoch 198/400: Train Loss = 0.0330 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.3892 | PSNR: 15.20 dB
# Epoch 199/400: Train Loss = 0.0332 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.4438 | PSNR: 14.62 dB
# Epoch 200/400: Train Loss = 0.0341 | Val Loss = 0.0323
#    [Generation Metrics] MSE: 0.3881 | PSNR: 15.21 dB
# Epoch 201/400: Train Loss = 0.0334 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4299 | PSNR: 14.76 dB
# Epoch 202/400: Train Loss = 0.0334 | Val Loss = 0.0353
#    [Generation Metrics] MSE: 0.4021 | PSNR: 15.05 dB
# Epoch 203/400: Train Loss = 0.0332 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.3630 | PSNR: 15.50 dB
# Epoch 204/400: Train Loss = 0.0340 | Val Loss = 0.0329
#    [Generation Metrics] MSE: 0.3972 | PSNR: 15.11 dB
# Epoch 205/400: Train Loss = 0.0331 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.4022 | PSNR: 15.05 dB
# Epoch 206/400: Train Loss = 0.0332 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.3951 | PSNR: 15.13 dB
# Epoch 207/400: Train Loss = 0.0333 | Val Loss = 0.0358
#    [Generation Metrics] MSE: 0.4646 | PSNR: 14.43 dB
# Epoch 208/400: Train Loss = 0.0328 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.3542 | PSNR: 15.60 dB
# Epoch 209/400: Train Loss = 0.0334 | Val Loss = 0.0356
#    [Generation Metrics] MSE: 0.3558 | PSNR: 15.58 dB
# Epoch 210/400: Train Loss = 0.0336 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.5061 | PSNR: 14.05 dB
# Epoch 211/400: Train Loss = 0.0328 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4182 | PSNR: 14.88 dB
# Epoch 212/400: Train Loss = 0.0337 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.4107 | PSNR: 14.96 dB
# Epoch 213/400: Train Loss = 0.0338 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.4076 | PSNR: 14.99 dB
# Epoch 214/400: Train Loss = 0.0331 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4163 | PSNR: 14.90 dB
# Epoch 215/400: Train Loss = 0.0333 | Val Loss = 0.0321
#    [Generation Metrics] MSE: 0.4676 | PSNR: 14.40 dB
# Epoch 216/400: Train Loss = 0.0336 | Val Loss = 0.0319
#    [Generation Metrics] MSE: 0.3788 | PSNR: 15.31 dB
# Epoch 217/400: Train Loss = 0.0335 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.4365 | PSNR: 14.70 dB
# Epoch 218/400: Train Loss = 0.0336 | Val Loss = 0.0336
#    [Generation Metrics] MSE: 0.4153 | PSNR: 14.91 dB
# Epoch 219/400: Train Loss = 0.0332 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.3342 | PSNR: 15.86 dB
#    --> Best MSE model saved.
# Epoch 220/400: Train Loss = 0.0331 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.3585 | PSNR: 15.55 dB
# Epoch 221/400: Train Loss = 0.0339 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.3886 | PSNR: 15.20 dB
# Epoch 222/400: Train Loss = 0.0338 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.4665 | PSNR: 14.41 dB
# Epoch 223/400: Train Loss = 0.0336 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.4141 | PSNR: 14.93 dB
# Epoch 224/400: Train Loss = 0.0329 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.4232 | PSNR: 14.83 dB
# Epoch 225/400: Train Loss = 0.0338 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4488 | PSNR: 14.58 dB
# Epoch 226/400: Train Loss = 0.0335 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.4063 | PSNR: 15.01 dB
# Epoch 227/400: Train Loss = 0.0328 | Val Loss = 0.0352
#    [Generation Metrics] MSE: 0.3841 | PSNR: 15.25 dB
# Epoch 228/400: Train Loss = 0.0333 | Val Loss = 0.0326
#    [Generation Metrics] MSE: 0.5060 | PSNR: 14.06 dB
# Epoch 229/400: Train Loss = 0.0334 | Val Loss = 0.0320
#    [Generation Metrics] MSE: 0.3568 | PSNR: 15.57 dB
# Epoch 230/400: Train Loss = 0.0332 | Val Loss = 0.0323
#    [Generation Metrics] MSE: 0.4445 | PSNR: 14.62 dB
# Epoch 231/400: Train Loss = 0.0337 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4012 | PSNR: 15.06 dB
# Epoch 232/400: Train Loss = 0.0331 | Val Loss = 0.0321
#    [Generation Metrics] MSE: 0.4597 | PSNR: 14.47 dB
# Epoch 233/400: Train Loss = 0.0328 | Val Loss = 0.0327
#    [Generation Metrics] MSE: 0.3640 | PSNR: 15.49 dB
# Epoch 234/400: Train Loss = 0.0335 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.3878 | PSNR: 15.21 dB
# Epoch 235/400: Train Loss = 0.0330 | Val Loss = 0.0345
#    [Generation Metrics] MSE: 0.4099 | PSNR: 14.97 dB
# Epoch 236/400: Train Loss = 0.0333 | Val Loss = 0.0314
#    [Generation Metrics] MSE: 0.3774 | PSNR: 15.33 dB
# Epoch 237/400: Train Loss = 0.0331 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.4243 | PSNR: 14.82 dB
# Epoch 238/400: Train Loss = 0.0339 | Val Loss = 0.0326
#    [Generation Metrics] MSE: 0.4047 | PSNR: 15.02 dB
# Epoch 239/400: Train Loss = 0.0333 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4103 | PSNR: 14.97 dB
# Epoch 240/400: Train Loss = 0.0332 | Val Loss = 0.0357
#    [Generation Metrics] MSE: 0.4163 | PSNR: 14.90 dB
# Epoch 241/400: Train Loss = 0.0328 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.3891 | PSNR: 15.20 dB
# Epoch 242/400: Train Loss = 0.0332 | Val Loss = 0.0329
#    [Generation Metrics] MSE: 0.4392 | PSNR: 14.67 dB
# Epoch 243/400: Train Loss = 0.0339 | Val Loss = 0.0313
#    [Generation Metrics] MSE: 0.3370 | PSNR: 15.82 dB
# Epoch 244/400: Train Loss = 0.0333 | Val Loss = 0.0329
#    [Generation Metrics] MSE: 0.4114 | PSNR: 14.95 dB
# Epoch 245/400: Train Loss = 0.0334 | Val Loss = 0.0349
#    [Generation Metrics] MSE: 0.4091 | PSNR: 14.98 dB
# Epoch 246/400: Train Loss = 0.0330 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.3288 | PSNR: 15.93 dB
#    --> Best MSE model saved.
# Epoch 247/400: Train Loss = 0.0335 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4223 | PSNR: 14.84 dB
# Epoch 248/400: Train Loss = 0.0328 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4409 | PSNR: 14.65 dB
# Epoch 249/400: Train Loss = 0.0328 | Val Loss = 0.0310
#    [Generation Metrics] MSE: 0.3161 | PSNR: 16.10 dB
#    --> Best MSE model saved.
# Epoch 250/400: Train Loss = 0.0330 | Val Loss = 0.0323
#    [Generation Metrics] MSE: 0.3878 | PSNR: 15.21 dB
# Epoch 251/400: Train Loss = 0.0333 | Val Loss = 0.0319
#    [Generation Metrics] MSE: 0.4509 | PSNR: 14.56 dB
# Epoch 252/400: Train Loss = 0.0324 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.3722 | PSNR: 15.39 dB
# Epoch 253/400: Train Loss = 0.0331 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.3942 | PSNR: 15.14 dB
# Epoch 254/400: Train Loss = 0.0326 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4020 | PSNR: 15.05 dB
# Epoch 255/400: Train Loss = 0.0335 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.3990 | PSNR: 15.09 dB
# Epoch 256/400: Train Loss = 0.0335 | Val Loss = 0.0328
#    [Generation Metrics] MSE: 0.3757 | PSNR: 15.35 dB
# Epoch 257/400: Train Loss = 0.0330 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4106 | PSNR: 14.96 dB
# Epoch 258/400: Train Loss = 0.0324 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.4037 | PSNR: 15.04 dB
# Epoch 259/400: Train Loss = 0.0327 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.3751 | PSNR: 15.35 dB
# Epoch 260/400: Train Loss = 0.0331 | Val Loss = 0.0358
#    [Generation Metrics] MSE: 0.4085 | PSNR: 14.98 dB
# Epoch 261/400: Train Loss = 0.0334 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4522 | PSNR: 14.54 dB
# Epoch 262/400: Train Loss = 0.0326 | Val Loss = 0.0318
#    [Generation Metrics] MSE: 0.4243 | PSNR: 14.82 dB
# Epoch 263/400: Train Loss = 0.0331 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.4834 | PSNR: 14.25 dB
# Epoch 264/400: Train Loss = 0.0333 | Val Loss = 0.0337
#    [Generation Metrics] MSE: 0.4703 | PSNR: 14.37 dB
# Epoch 265/400: Train Loss = 0.0333 | Val Loss = 0.0323
#    [Generation Metrics] MSE: 0.3638 | PSNR: 15.49 dB
# Epoch 266/400: Train Loss = 0.0328 | Val Loss = 0.0325
#    [Generation Metrics] MSE: 0.3237 | PSNR: 16.00 dB
# Epoch 267/400: Train Loss = 0.0333 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.4327 | PSNR: 14.73 dB
# Epoch 268/400: Train Loss = 0.0336 | Val Loss = 0.0314
#    [Generation Metrics] MSE: 0.4680 | PSNR: 14.39 dB
# Epoch 269/400: Train Loss = 0.0331 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.3937 | PSNR: 15.14 dB
# Epoch 270/400: Train Loss = 0.0335 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.3849 | PSNR: 15.24 dB
# Epoch 271/400: Train Loss = 0.0331 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.3607 | PSNR: 15.52 dB
# Epoch 272/400: Train Loss = 0.0329 | Val Loss = 0.0349
#    [Generation Metrics] MSE: 0.3692 | PSNR: 15.42 dB
# Epoch 273/400: Train Loss = 0.0329 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.4133 | PSNR: 14.93 dB
# Epoch 274/400: Train Loss = 0.0328 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.4480 | PSNR: 14.58 dB
# Epoch 275/400: Train Loss = 0.0334 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.4260 | PSNR: 14.80 dB
# Epoch 276/400: Train Loss = 0.0329 | Val Loss = 0.0336
#    [Generation Metrics] MSE: 0.4478 | PSNR: 14.59 dB
# Epoch 277/400: Train Loss = 0.0331 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.4535 | PSNR: 14.53 dB
# Epoch 278/400: Train Loss = 0.0334 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.4138 | PSNR: 14.93 dB
# Epoch 279/400: Train Loss = 0.0329 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.4079 | PSNR: 14.99 dB
# Epoch 280/400: Train Loss = 0.0332 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.4440 | PSNR: 14.62 dB
# Epoch 281/400: Train Loss = 0.0326 | Val Loss = 0.0347
#    [Generation Metrics] MSE: 0.4429 | PSNR: 14.63 dB
# Epoch 282/400: Train Loss = 0.0332 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4178 | PSNR: 14.89 dB
# Epoch 283/400: Train Loss = 0.0333 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.3463 | PSNR: 15.70 dB
# Epoch 284/400: Train Loss = 0.0328 | Val Loss = 0.0327
#    [Generation Metrics] MSE: 0.4213 | PSNR: 14.85 dB
# Epoch 285/400: Train Loss = 0.0333 | Val Loss = 0.0328
#    [Generation Metrics] MSE: 0.4591 | PSNR: 14.48 dB
# Epoch 286/400: Train Loss = 0.0336 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.3667 | PSNR: 15.45 dB
# Epoch 287/400: Train Loss = 0.0329 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.4442 | PSNR: 14.62 dB
# Epoch 288/400: Train Loss = 0.0332 | Val Loss = 0.0326
#    [Generation Metrics] MSE: 0.4869 | PSNR: 14.22 dB
# Epoch 289/400: Train Loss = 0.0326 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.3709 | PSNR: 15.40 dB
# Epoch 290/400: Train Loss = 0.0331 | Val Loss = 0.0331
#    [Generation Metrics] MSE: 0.4506 | PSNR: 14.56 dB
# Epoch 291/400: Train Loss = 0.0333 | Val Loss = 0.0326
#    [Generation Metrics] MSE: 0.4363 | PSNR: 14.70 dB
# Epoch 292/400: Train Loss = 0.0326 | Val Loss = 0.0311
#    [Generation Metrics] MSE: 0.3901 | PSNR: 15.18 dB
# Epoch 293/400: Train Loss = 0.0322 | Val Loss = 0.0345
#    [Generation Metrics] MSE: 0.3987 | PSNR: 15.09 dB
# Epoch 294/400: Train Loss = 0.0327 | Val Loss = 0.0334
#    [Generation Metrics] MSE: 0.4825 | PSNR: 14.26 dB
# Epoch 295/400: Train Loss = 0.0330 | Val Loss = 0.0354
#    [Generation Metrics] MSE: 0.4140 | PSNR: 14.93 dB
# Epoch 296/400: Train Loss = 0.0339 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.4064 | PSNR: 15.01 dB
# Epoch 297/400: Train Loss = 0.0327 | Val Loss = 0.0336
#    [Generation Metrics] MSE: 0.4013 | PSNR: 15.06 dB
# Epoch 298/400: Train Loss = 0.0329 | Val Loss = 0.0329
#    [Generation Metrics] MSE: 0.3571 | PSNR: 15.57 dB
# Epoch 299/400: Train Loss = 0.0334 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.4676 | PSNR: 14.40 dB
# Epoch 300/400: Train Loss = 0.0326 | Val Loss = 0.0348
#    [Generation Metrics] MSE: 0.3888 | PSNR: 15.20 dB
# Epoch 301/400: Train Loss = 0.0333 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.4472 | PSNR: 14.59 dB
# Epoch 302/400: Train Loss = 0.0329 | Val Loss = 0.0338
#    [Generation Metrics] MSE: 0.3995 | PSNR: 15.08 dB
# Epoch 303/400: Train Loss = 0.0334 | Val Loss = 0.0334
#    [Generation Metrics] MSE: 0.4112 | PSNR: 14.96 dB
# Epoch 304/400: Train Loss = 0.0332 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.3427 | PSNR: 15.75 dB
# Epoch 305/400: Train Loss = 0.0330 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.4025 | PSNR: 15.05 dB
# Epoch 306/400: Train Loss = 0.0336 | Val Loss = 0.0328
#    [Generation Metrics] MSE: 0.4089 | PSNR: 14.98 dB
# Epoch 307/400: Train Loss = 0.0335 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.3714 | PSNR: 15.40 dB
# Epoch 308/400: Train Loss = 0.0332 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.4248 | PSNR: 14.81 dB
# Epoch 309/400: Train Loss = 0.0328 | Val Loss = 0.0335
#    [Generation Metrics] MSE: 0.4626 | PSNR: 14.44 dB
# Epoch 310/400: Train Loss = 0.0334 | Val Loss = 0.0337
#    [Generation Metrics] MSE: 0.3809 | PSNR: 15.29 dB
# Epoch 311/400: Train Loss = 0.0338 | Val Loss = 0.0319
#    [Generation Metrics] MSE: 0.3853 | PSNR: 15.24 dB
# Epoch 312/400: Train Loss = 0.0332 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.4095 | PSNR: 14.97 dB
# Epoch 313/400: Train Loss = 0.0331 | Val Loss = 0.0321
#    [Generation Metrics] MSE: 0.3814 | PSNR: 15.28 dB
# Epoch 314/400: Train Loss = 0.0327 | Val Loss = 0.0327
#    [Generation Metrics] MSE: 0.3707 | PSNR: 15.41 dB
# Epoch 315/400: Train Loss = 0.0326 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.3258 | PSNR: 15.97 dB
# Epoch 316/400: Train Loss = 0.0334 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.3994 | PSNR: 15.08 dB
# Epoch 317/400: Train Loss = 0.0329 | Val Loss = 0.0318
#    [Generation Metrics] MSE: 0.4786 | PSNR: 14.30 dB
# Epoch 318/400: Train Loss = 0.0330 | Val Loss = 0.0316
#    [Generation Metrics] MSE: 0.3536 | PSNR: 15.61 dB
# Epoch 319/400: Train Loss = 0.0331 | Val Loss = 0.0357
#    [Generation Metrics] MSE: 0.3902 | PSNR: 15.18 dB
# Epoch 320/400: Train Loss = 0.0328 | Val Loss = 0.0343
#    [Generation Metrics] MSE: 0.3588 | PSNR: 15.55 dB
# Epoch 321/400: Train Loss = 0.0334 | Val Loss = 0.0332
#    [Generation Metrics] MSE: 0.4571 | PSNR: 14.50 dB
# Epoch 322/400: Train Loss = 0.0325 | Val Loss = 0.0346
#    [Generation Metrics] MSE: 0.4125 | PSNR: 14.94 dB
# Epoch 323/400: Train Loss = 0.0331 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.3690 | PSNR: 15.43 dB
# Epoch 324/400: Train Loss = 0.0333 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.4580 | PSNR: 14.49 dB
# Epoch 325/400: Train Loss = 0.0332 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.4027 | PSNR: 15.05 dB
# Epoch 326/400: Train Loss = 0.0328 | Val Loss = 0.0321
#    [Generation Metrics] MSE: 0.4556 | PSNR: 14.51 dB
# Epoch 327/400: Train Loss = 0.0331 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.4153 | PSNR: 14.91 dB
# Epoch 328/400: Train Loss = 0.0326 | Val Loss = 0.0309
#    [Generation Metrics] MSE: 0.4188 | PSNR: 14.88 dB
# Epoch 329/400: Train Loss = 0.0336 | Val Loss = 0.0339
#    [Generation Metrics] MSE: 0.4128 | PSNR: 14.94 dB
# Epoch 330/400: Train Loss = 0.0342 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.4273 | PSNR: 14.79 dB
# Epoch 331/400: Train Loss = 0.0329 | Val Loss = 0.0333
#    [Generation Metrics] MSE: 0.4095 | PSNR: 14.97 dB
# Epoch 332/400: Train Loss = 0.0324 | Val Loss = 0.0324
#    [Generation Metrics] MSE: 0.3842 | PSNR: 15.25 dB
# Epoch 333/400: Train Loss = 0.0332 | Val Loss = 0.0315
#    [Generation Metrics] MSE: 0.4279 | PSNR: 14.78 dB
# Epoch 334/400: Train Loss = 0.0327 | Val Loss = 0.0329
#    [Generation Metrics] MSE: 0.3970 | PSNR: 15.11 dB
# Epoch 335/400: Train Loss = 0.0337 | Val Loss = 0.0326
#    [Generation Metrics] MSE: 0.3964 | PSNR: 15.12 dB
# Epoch 336/400: Train Loss = 0.0325 | Val Loss = 0.0351
#    [Generation Metrics] MSE: 0.4139 | PSNR: 14.93 dB
# Epoch 337/400: Train Loss = 0.0330 | Val Loss = 0.0327
#    [Generation Metrics] MSE: 0.3798 | PSNR: 15.30 dB
# Epoch 338/400: Train Loss = 0.0330 | Val Loss = 0.0322
#    [Generation Metrics] MSE: 0.4012 | PSNR: 15.06 dB
# Epoch 339/400: Train Loss = 0.0325 | Val Loss = 0.0330
#    [Generation Metrics] MSE: 0.4085 | PSNR: 14.98 dB
# Epoch 340/400: Train Loss = 0.0331 | Val Loss = 0.0340
#    [Generation Metrics] MSE: 0.4479 | PSNR: 14.58 dB
# Epoch 341/400: Train Loss = 0.0326 | Val Loss = 0.0337
#    [Generation Metrics] MSE: 0.4045 | PSNR: 15.03 dB
# Epoch 342/400: Train Loss = 0.0332 | Val Loss = 0.0342
#    [Generation Metrics] MSE: 0.3616 | PSNR: 15.51 dB
# Epoch 343/400: Train Loss = 0.0334 | Val Loss = 0.0344
#    [Generation Metrics] MSE: 0.3672 | PSNR: 15.45 dB
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 13
#       7 rd_val_loss = None
#       9 for epoch in range(num_epochs):
#      10     #train_loss, e_mse_loss, e_rd_loss= train_one_epoch(cond_diffusion, train_loader, optimizer, device)
#      11     #val_loss, iq_val_loss, rd_val_loss, gen_mse, gen_psnr, rd_mse = validate(cond_diffusion, val_loader, device)
# ---> 13     train_loss= train_one_epoch(cond_diffusion, train_loader, optimizer, device)
#      14     val_loss, gen_mse, gen_psnr = validate(cond_diffusion, val_loader, device)
#      16     train_losses.append(train_loss)
#
# File ~/Desktop/Heavy Detector/Heavy-Clutter-Detection/finalDiffusion/utils/trainer.py:73, in train_one_epoch(diffusion, dataloader, optimizer, device, use_standard_loss, use_rd_loss)
#      71     loss.backward()
#      72     optimizer.step()
# ---> 73     epoch_loss += loss.item()
#      75 return epoch_loss / len(dataloader)
#
# KeyboardInterrupt:

# %%
checkpoint_path = "/home/hawk/Desktop/Heavy Detector/Heavy-Clutter-Detection/finalDiffusion/try_bench_again_bend005.pth"
run_inference(cond_diffusion , norm_val_dataset, checkpoint_path, device)
